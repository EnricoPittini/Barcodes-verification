# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
import imutils
import math
import matplotlib.patches as patches
import time

# %%
import importlib  

module = importlib.import_module('1) APIs')
detect_and_refine_boundingBox = module.detect_and_refine_boundingBox

# %%
from os import listdir
from os.path import isfile, join
images_paths = [f for f in listdir('../images') if isfile(join('../images', f))]

# %%
# %%time
# %matplotlib inline
image_path = f'../images/{images_paths[0]}'
roi_image_ref, bb_points_sorted_rot_ref, bb_width_ref, bb_height_ref = detect_and_refine_boundingBox(image_path, visualization_dict='all')
# Out:
# Wall time: 3.76 s

# %%
# %%time
# %matplotlib notebook
image_path = f'../images/{images_paths[0]}'
roi_image_ref, bb_points_sorted_rot_ref, bb_width_ref, bb_height_ref = detect_and_refine_boundingBox(image_path, visualization_dict='all')
# Out:
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="720">
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="432">
# Wall time: 990 ms
