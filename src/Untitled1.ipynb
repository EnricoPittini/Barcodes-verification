# %%
from verify_barcode import verify_barcode

# %%
image_path = '../dataset/UPC#06.bmp'
visualization_dict = {
  'visualize_refinedRoi': True,
  'visualize_scanlines_qualityParameters':True
}

detection_dict, rotation_dict, refinement_dict, overall_quality_parameters_dict = verify_barcode(image_path, visualization_dict=visualization_dict, verbose_timing=True, create_output_file=True)
# Out:
# TIMING INFORMATION
# 	Detect bounding box: 0.017584800720214844
# 	Rotate bounding box: 0.007986307144165039
# 	Refine ROI image: 0.05537009239196777
# 	Compute quality parameters: 0.811732292175293
