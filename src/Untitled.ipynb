# %%
import cv2
import matplotlib.pyplot as plt

# %%
from os import listdir
from os.path import isfile, join
images_paths = [f for f in listdir('../dataset') if isfile(join('../dataset', f))]

# %%
image_path = f'../dataset/{images_paths[26]}'
image = cv2.imread(image_path)
plt.imshow(image)
plt.title('Image UPC#06')
# Out:
# Text(0.5, 1.0, 'Image UPC#06')

# %%
image_path = f'../dataset/{images_paths[10]}'
image = cv2.imread(image_path)
plt.imshow(image)
plt.title('Image EAN-UPC-DEFECTS IMGB')
# Out:
# Text(0.5, 1.0, 'Image EAN-UPC-DEFECTS IMGB')

# %%
image_path = f'../dataset/{images_paths[4]}'
image = cv2.imread(image_path)
plt.imshow(image)
plt.title('Image C39_4.4LOW')
# Out:
# Text(0.5, 1.0, 'Image C39_4.4LOW')

# %%
image_path = f'../dataset/{images_paths[16]}'
image = cv2.imread(image_path)
plt.imshow(image)
plt.title('Image EAN128-MASTER IMGB')
# Out:
# Text(0.5, 1.0, 'Image EAN128-MASTER IMGB')

# %%
image_path = f'../dataset/{images_paths[8]}'
image = cv2.imread(image_path)
plt.imshow(image)
plt.title('Image EAN-UPC-CONTRAST IMGB')
# Out:
# Text(0.5, 1.0, 'Image EAN-UPC-CONTRAST IMGB')

# %%
image_path = f'../dataset/{images_paths[23]}'
print(image_path)
image = cv2.imread(image_path)
plt.imshow(image)
plt.title('Image UPC#03, SC grade \'A\'')
# Out:
# ../dataset/UPC#03.BMP
# Text(0.5, 1.0, "Image UPC#03, SC grade 'A'")

# %%
image_path = f'../dataset/{images_paths[24]}'
print(image_path)
image = cv2.imread(image_path)
plt.imshow(image)
plt.title('Image UPC#04, SC grade \'B\'')
# Out:
# ../dataset/UPC#04.BMP
# Text(0.5, 1.0, "Image UPC#04, SC grade 'B'")

# %%
image_path = f'../dataset/{images_paths[25]}'
print(image_path)
image = cv2.imread(image_path)
plt.imshow(image)
plt.title('Image UPC#05, SC grade \'C\'')
# Out:
# ../dataset/UPC#05.BMP
# Text(0.5, 1.0, "Image UPC#05, SC grade 'C'")

# %%
image_path = f'../dataset/{images_paths[26]}'
print(image_path)
image = cv2.imread(image_path)
plt.imshow(image)
plt.title('Image UPC#06, SC grade \'D\'')
# Out:
# ../dataset/UPC#06.BMP
# Text(0.5, 1.0, "Image UPC#06, SC grade 'D'")

# %%
image_path = f'../dataset/{images_paths[27]}'
print(image_path)
image = cv2.imread(image_path)
plt.imshow(image)
plt.title('Image UPC#07, SC grade \'F\'')
# Out:
# ../dataset/UPC#07.BMP
# Text(0.5, 1.0, "Image UPC#07, SC grade 'F'")

# %%
image_path = f'../dataset/{images_paths[28]}'
print(image_path)
image = cv2.imread(image_path)
plt.imshow(image)
plt.title('Image UPC#08, M grade \'A\'')
# Out:
# ../dataset/UPC#08.BMP
# Text(0.5, 1.0, "Image UPC#08, M grade 'A'")

# %%
image_path = f'../dataset/{images_paths[29]}'
print(image_path)
image = cv2.imread(image_path)
plt.imshow(image)
plt.title('Image UPC#09, M grade \'B\'')
# Out:
# ../dataset/UPC#09.BMP
# Text(0.5, 1.0, "Image UPC#09, M grade 'B'")

# %%
image_path = f'../dataset/{images_paths[30]}'
print(image_path)
image = cv2.imread(image_path)
plt.imshow(image)
plt.title('Image UPC#10, M grade \'C\'')
# Out:
# ../dataset/UPC#10.BMP
# Text(0.5, 1.0, "Image UPC#10, M grade 'C'")

# %%
image_path = f'../dataset/{images_paths[31]}'
print(image_path)
image = cv2.imread(image_path)
plt.imshow(image)
plt.title('Image UPC#11, M grade \'D\'')
# Out:
# ../dataset/UPC#11.BMP
# Text(0.5, 1.0, "Image UPC#11, M grade 'D'")

# %%
image_path = f'../dataset/{images_paths[32]}'
print(image_path)
image = cv2.imread(image_path)
plt.imshow(image)
plt.title('Image UPC#12, M grade \'F\'')
# Out:
# ../dataset/UPC#12.BMP
# Text(0.5, 1.0, "Image UPC#12, M grade 'F'")

# %%
image_path = f'../dataset/{images_paths[18]}'
print(image_path)
image = cv2.imread(image_path)
plt.imshow(image)
plt.title('Image I25-DEFECTS IMGB, defect spot')
# Out:
# ../dataset/I25-DEFECTS IMGB.BMP
# Text(0.5, 1.0, 'Image I25-DEFECTS IMGB, defect spot')

# %%
image_path = f'../dataset/{images_paths[4]}'
print(image_path)
image = cv2.imread(image_path)
plt.imshow(image)
plt.title('Image C39_4.4LOW, defect void')
# Out:
# ../dataset/C39_4.4LOW.BMP
# Text(0.5, 1.0, 'Image C39_4.4LOW, defect void')

# %%
image_path = f'../dataset/{images_paths[33]}'
print(image_path)
image = cv2.imread(image_path)
plt.imshow(image)
plt.title('Image UPC#13, D grade \'A\'')
# Out:
# ../dataset/UPC#13.BMP
# Text(0.5, 1.0, "Image UPC#13, D grade 'A'")

# %%
image_path = f'../dataset/{images_paths[34]}'
print(image_path)
image = cv2.imread(image_path)
plt.imshow(image)
plt.title('Image UPC#14, D grade \'B\'')
# Out:
# ../dataset/UPC#14.BMP
# Text(0.5, 1.0, "Image UPC#14, D grade 'B'")

# %%
image_path = f'../dataset/{images_paths[35]}'
print(image_path)
image = cv2.imread(image_path)
plt.imshow(image)
plt.title('Image UPC#15, D grade \'C\'')
# Out:
# ../dataset/UPC#15.BMP
# Text(0.5, 1.0, "Image UPC#15, D grade 'C'")

# %%
image_path = f'../dataset/{images_paths[36]}'
print(image_path)
image = cv2.imread(image_path)
plt.imshow(image)
plt.title('Image UPC#16, D grade \'D\'')
# Out:
# ../dataset/UPC#16.BMP
# Text(0.5, 1.0, "Image UPC#16, D grade 'D'")

# %%
image_path = f'../dataset/{images_paths[37]}'
print(image_path)
image = cv2.imread(image_path)
plt.imshow(image)
plt.title('Image UPC#17, D grade \'F\'')
# Out:
# ../dataset/UPC#17.BMP
# Text(0.5, 1.0, "Image UPC#17, D grade 'F'")

# %%
image_path = f'../dataset/{images_paths[38]}'
print(image_path)
image = cv2.imread(image_path)
plt.imshow(image)
plt.title('Image UPC#18, D grade \'A\'')
# Out:
# ../dataset/UPC#18.BMP
# Text(0.5, 1.0, "Image UPC#18, D grade 'A'")

# %%
image_path = f'../dataset/{images_paths[39]}'
print(image_path)
image = cv2.imread(image_path)
plt.imshow(image)
plt.title('Image UPC#19, D grade \'B\'')
# Out:
# ../dataset/UPC#19.BMP
# Text(0.5, 1.0, "Image UPC#19, D grade 'B'")

# %%
image_path = f'../dataset/{images_paths[40]}'
print(image_path)
image = cv2.imread(image_path)
plt.imshow(image)
plt.title('Image UPC#20, D grade \'C\'')
# Out:
# ../dataset/UPC#20.BMP
# Text(0.5, 1.0, "Image UPC#20, D grade 'C'")

# %%
image_path = f'../dataset/{images_paths[41]}'
print(image_path)
image = cv2.imread(image_path)
plt.imshow(image)
plt.title('Image UPC#21, D grade \'D\'')
# Out:
# ../dataset/UPC#21.BMP
# Text(0.5, 1.0, "Image UPC#21, D grade 'D'")

# %%
image_path = f'../dataset/{images_paths[42]}'
print(image_path)
image = cv2.imread(image_path)
plt.imshow(image)
plt.title('Image UPC#22, D grade \'F\'')
# Out:
# ../dataset/UPC#22.BMP
# Text(0.5, 1.0, "Image UPC#22, D grade 'F'")
